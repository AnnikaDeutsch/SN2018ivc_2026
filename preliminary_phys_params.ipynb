# %% [markdown]
# The purpose of this notebook is to get a rough idea of R, v, and B for each shock component, assuming SSA is dominant for each. So the values of K1, K2, and p might not be even close to correct, but it can be informative as a starting point.

# %%
# %reload_ext autoreload 
# %autoreload 2 

# load functions
import functions

# imports
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Component 1 (FFA)

# %%
# load in the parameters for the FFA component

K1_e1_FFA = 34.5
K2_e1_FFA = 3.75
p_e1_FFA = 1.65

K1_e2_FFA = 18.5
K2_e2_FFA = 5.5
p_e2_FFA = 1.65

K1_e3_FFA = 44.5
K2_e3_FFA = 3.75
p_e3_FFA = 1.65

# %% [markdown]
# ## Component 2

# %%
# load in the parameters for the first SSA component

K1_e1_SSA = 75.0
K2_e1_SSA = 0.07
p_e1_SSA = 3.85

K1_e1_SSA = 25.0
K2_e1_SSA = 0.27
p_e1_SSA = 3.85

K1_e1_SSA = 115.0
K2_e1_SSA = 0.06
p_e1_SSA = 3.85

K1_e1_SSA = 75.0
K2_e1_SSA = 0.07
p_e1_SSA = 3.85

# %% [markdown]
# ## Component 3
