# %%
import numpy as np
import matplotlib.pyplot as plt
import emcee
from astropy.io import ascii
import corner
import os
from timeit import default_timer as timer
import matplotlib.colors as colors
import matplotlib.cm as cmx
from scipy.optimize import least_squares, curve_fit
from scipy.stats import f

# %%
b4data1993j=np.loadtxt('93j-610.dat',dtype=float, skiprows=0)
b4ul1993j=np.loadtxt('93j-610-ul.dat',dtype=float,skiprows=0)
data1993j=np.loadtxt('93j-l.dat',dtype=float, skiprows=0)
ul1993j=np.loadtxt('93j-l-ul.dat',dtype=float,skiprows=0)
cdata1993j=np.loadtxt('93j-c.dat',dtype=float, skiprows=0)
cul1993j=np.loadtxt('93j-c-ul.dat',dtype=float,skiprows=0)
xdata1993j=np.loadtxt('93j-x.dat',dtype=float, skiprows=0)
xul1993j=np.loadtxt('93j-x-ul.dat',dtype=float,skiprows=0)
kudata1993j=np.loadtxt('93j-ku.dat',dtype=float, skiprows=0)
kuul1993j=np.loadtxt('93j-ku-ul.dat',dtype=float,skiprows=0)
kdata1993j=np.loadtxt('93j-k.dat',dtype=float, skiprows=0)
kul1993j=np.loadtxt('93j-k-ul.dat',dtype=float,skiprows=0)

data2001gd=np.loadtxt('01gd-l.dat',dtype=float, skiprows=0)
ul2001gd=np.loadtxt('01gd-l-ul.dat',dtype=float,skiprows=0)
cdata2001gd=np.loadtxt('01gd-c.dat',dtype=float, skiprows=0)
cul2001gd=np.loadtxt('01gd-c-ul.dat',dtype=float,skiprows=0)
xdata2001gd=np.loadtxt('01gd-x.dat',dtype=float, skiprows=0)
xul2001gd=np.loadtxt('01gd-x-ul.dat',dtype=float,skiprows=0)
kudata2001gd=np.loadtxt('01gd-ku.dat',dtype=float, skiprows=0)
kuul2001gd=np.loadtxt('01gd-ku-ul.dat',dtype=float,skiprows=0)
kdata2001gd=np.loadtxt('01gd-k.dat',dtype=float, skiprows=0)
kul2001gd=np.loadtxt('01gd-k-ul.dat',dtype=float,skiprows=0)


data2001ig=np.loadtxt('01ig-l.dat',dtype=float, skiprows=0)
ul2001ig=np.loadtxt('01ig-l-ul.dat',dtype=float,skiprows=0)
sdata2001ig=np.loadtxt('2001ig_s.dat',dtype=float, skiprows=0)
cdata2001ig=np.loadtxt('01ig-c.dat',dtype=float, skiprows=0)
xdata2001ig=np.loadtxt('01ig-x.dat',dtype=float, skiprows=0)
kudata2001ig=np.loadtxt('01ig-ku.dat',dtype=float, skiprows=0)
kdata2001ig=np.loadtxt('01ig-k.dat',dtype=float, skiprows=0)

data2003bg=np.loadtxt('03bg-l.dat',dtype=float, skiprows=0)
cdata2003bg=np.loadtxt('03bg-c.dat',dtype=float, skiprows=0)
xdata2003bg=np.loadtxt('03bg-x.dat',dtype=float, skiprows=0)
kudata2003bg=np.loadtxt('03bg-ku.dat',dtype=float, skiprows=0)
kdata2003bg=np.loadtxt('03bg-k.dat',dtype=float, skiprows=0)

cdata2010P=np.loadtxt('10P-c.dat',dtype=float, skiprows=0)
cul2010P=np.loadtxt('10P-c-ul.dat',dtype=float,skiprows=0)
xdata2010P=np.loadtxt('10P-x.dat',dtype=float, skiprows=0)

data2011dh=np.loadtxt('11dh-l.dat',dtype=float, skiprows=0)
ul2011dh=np.loadtxt('11dh-l-ul.dat',dtype=float,skiprows=0)
sdata2011dh=np.loadtxt('2011dh_s.dat',dtype=float, skiprows=0)
cdata2011dh=np.loadtxt('11dh-c.dat',dtype=float, skiprows=0)
xdata2011dh=np.loadtxt('11dh-x.dat',dtype=float, skiprows=0)
kdata2011dh=np.loadtxt('11dh-k.dat',dtype=float, skiprows=0)



data2013df=np.loadtxt('13df-l.dat',dtype=float, skiprows=0)
#ul2013df = np.loadtxt('ul2013df.dat')
xdata2013df=np.loadtxt('13df-x.dat',dtype=float, skiprows=0)
xul2013df=np.loadtxt('13df-x-ul.dat',dtype=float,skiprows=0)
cdata2013df=np.loadtxt('13df-c.dat',dtype=float, skiprows=0)
cul2013df=np.loadtxt('13df-c-ul.dat',dtype=float,skiprows=0)
kudata2013df=np.loadtxt('13df-ku.dat',dtype=float, skiprows=0)

cdata2016bas=np.loadtxt('16bas-c.dat',dtype=float, skiprows=0)
xdata2016bas=np.loadtxt('16bas-x.dat',dtype=float, skiprows=0)

b4data2016gkg=np.loadtxt('16gkg-610.dat',dtype=float, skiprows=0)
b4uldata2016gkg=np.loadtxt('16gkg-610-ul.dat',dtype=float, skiprows=0)
data2016gkg=np.loadtxt('16gkg-l.dat',dtype=float, skiprows=0)
xdata2016gkg=np.loadtxt('16gkg-x.dat',dtype=float,skiprows=0)
cdata2016gkg=np.loadtxt('16gkg-c.dat',dtype=float, skiprows=0)
sdata2016gkg=np.loadtxt('2016gkg_s.dat',dtype=float, skiprows=0)
kdata2016gkg=np.loadtxt('16gkg-k.dat',dtype=float,skiprows=0)

b4data2022crv=np.loadtxt('22crv-610.dat',dtype=float,skiprows=0)
b4uldata2022crv=np.loadtxt('22crv-610-ul.dat',dtype=float,skiprows=0)
data2022crv=np.loadtxt('22crv-l.dat',dtype=float, skiprows=0)
cdata2022crv=np.loadtxt('22crv-c.dat',dtype=float,skiprows=0)
xdata2022crv=np.loadtxt('22crv-x.dat',dtype=float,skiprows=0)



xdata2008ax=np.loadtxt('08ax-x.dat',dtype=float, skiprows=0)
cdata2008ax=np.loadtxt('08ax-c.dat',dtype=float, skiprows=0)
kdata2008ax=np.loadtxt('08ax-k.dat',dtype=float, skiprows=0)

# %%
fig, axs = plt.subplots(1, 4, figsize=(23, 8))
plt.subplots_adjust(wspace=0, hspace=0)

for ax in axs:
    ax.tick_params(
        which='both', direction='in',
        top=True, bottom=True, left=True, right=True,
        labelsize=14, width=2)


plt.subplot(141)
#plt.plot(time,y[0],'r-')


plt.plot(data1993j[:,0],data1993j[:,1],color='blue', linewidth=2, linestyle='--')
plt.plot(ul1993j[:,0],ul1993j[:,1],marker='v',markersize=14,linestyle='',markerfacecolor='skyblue',markeredgecolor='blue')
h_1993J=plt.errorbar(data1993j[:,0],data1993j[:,1],yerr=data1993j[:,2],marker='s',markersize=12,linestyle='',markerfacecolor='skyblue',markeredgecolor='blue',ecolor='blue',label='1993J')[0]

plt.plot(data2001ig[:,0],data2001ig[:,1],color='darkgoldenrod', linewidth=2, linestyle='--')
plt.plot(ul2001ig[:,0],ul2001ig[:,1],marker='v',markersize=14,linestyle='',markerfacecolor='goldenrod',markeredgecolor='darkgoldenrod')
h_2001ig=plt.errorbar(data2001ig[:,0],data2001ig[:,1],yerr=data2001ig[:,2],marker='o',markersize=14,linestyle='',markerfacecolor='goldenrod',markeredgecolor='darkgoldenrod',ecolor='darkgoldenrod',label='2001ig')[0]

plt.plot(data2003bg[:,0],data2003bg[:,1],color='peru', linewidth=2, linestyle='--')
h_2003bg=plt.errorbar(data2003bg[:,0],data2003bg[:,1],yerr=data2003bg[:,2],marker='o',markersize=14,linestyle='',markerfacecolor='lightsalmon',markeredgecolor='peru',ecolor='peru',label='2003bg')[0]

#plt.errorbar(data2008ax[:,0],data2008ax[:,1],yerr=data2008ax[:,2],marker='o',markersize=11,linestyle='',markerfacecolor='yellow',markeredgecolor='olive',ecolor='olive',label='2008ax')
plt.plot(data2011dh[:,0],data2011dh[:,1],color='rebeccapurple', linewidth=2, linestyle='--')
plt.plot(ul2011dh[:,0],ul2011dh[:,1],marker='v',markersize=14,linestyle='',markerfacecolor='mediumpurple',markeredgecolor='rebeccapurple')
h_2011dh=plt.errorbar(data2011dh[:,0],data2011dh[:,1],yerr=data2011dh[:,2],marker='s',markersize=12,linestyle='',markerfacecolor='mediumpurple',markeredgecolor='rebeccapurple',ecolor='rebeccapurple',label='2011dh')[0]

#plt.errorbar(data2011et[:,0],data2011et[:,1],yerr=data2011et[:,2],marker='o',markersize=11,linestyle='',markerfacecolor='lightpink',markeredgecolor='magenta',ecolor='magenta',label='2011et')

plt.plot(data2013df[:,0],data2013df[:,1],color='red', linewidth=2, linestyle='--')
#plt.plot(ul2013df[:,0],ul2013df[:,1],marker='v',markersize=11,linestyle='',markerfacecolor='salmon',markeredgecolor='r')
h_2013df=plt.errorbar(data2013df[:,0],data2013df[:,1],yerr=data2013df[:,2],marker='s',markersize=12,linestyle='',markerfacecolor='salmon',markeredgecolor='r',ecolor='r',label='2013df')[0]

plt.plot(data2016gkg[:,0],data2016gkg[:,1],color='teal', linewidth=2, linestyle='--')
#plt.plot(ul2016gkg[:,0],ul2016gkg[:,1],marker='v',markersize=11,linestyle='',markerfacecolor='cyan',markeredgecolor='teal')
h_2016gkg=plt.errorbar(data2016gkg[:,0],data2016gkg[:,1],yerr=data2016gkg[:,2],marker='s',markersize=12,linestyle='',markerfacecolor='cyan',markeredgecolor='teal',ecolor='teal',label='2016gkg')[0]

plt.plot(data2022crv[:,0],data2022crv[:,1],color='darkseagreen', linewidth=2, linestyle='--')
#plt.plot(ul2022crv[:,0],ul2022crv[:,1],marker='v',markersize=11,linestyle='',markerfacecolor='palegreen',markeredgecolor='darkseagreen')
h_2022crv=plt.errorbar(data2022crv[:,0],data2022crv[:,1],yerr=data2022crv[:,2],marker='o',markersize=14,linestyle='',markerfacecolor='palegreen',markeredgecolor='darkseagreen',ecolor='darkseagreen',label='2022crv')[0]

#plt.plot(data2020acat[:,0],data2020acat[:,1],color='darkred', linewidth=2, linestyle='--')
#plt.plot(ul2020acat[:,0],ul2020acat[:,1],marker='v',markersize=14,linestyle='',markerfacecolor='orangered',markeredgecolor='darkred')
#plt.errorbar(data2020acat[:,0],data2020acat[:,1],yerr=data2020acat[:,2],marker='o',markersize=14,linestyle='',markerfacecolor='orangered',markeredgecolor='darkred',ecolor='darkred',label='2020acat')
#plt.plot(8.51,5.75e27,marker='v',markersize=20,linestyle='',mew=3,zorder=29,markerfacecolor='grey',markeredgecolor='black',label='')
h_2025ulz=plt.plot(lul2025ulz[:,0],lul2025ulz[:,1],marker='v',markersize=20,linestyle='',mew=3,markerfacecolor='grey',markeredgecolor='black',label='AT2025ulz',zorder=61)[0]

plt.annotate(
    '',
    xy=(20,5.75e27),
    xytext=(9,5.75e27),
    arrowprops=dict(
        arrowstyle='->',
        color='black',
        lw=2,
        mutation_scale=20
    )
)
plt.ylabel(r'$ L_\nu$ (erg s$^{-1}$ Hz$^{-1}$))', fontsize=20)
plt.xlabel('Time (days)',fontsize=20)
plt.tick_params(which='both',direction='in',labelsize=16,length=6, width=2,labelleft=True,labelright=False,labelbottom=True,top=True,right=True)
#plt.tick_params(which='both',direction='in',labelsize=14,length=6, width=2,labelbottom=False,labelleft=False,labelright='false',top='true',right='true')
#plt.legend(loc='upper left', fontsize=14)
#plt.legend(loc='upper left', fontsize=14, handles=[h_1993J, h_2001ig, h_2003bg, h_2011dh, h_2013df, h_2016gkg, h_2022crv, h_2025ulz])
handles = [h_1993J, h_2001ig, h_2003bg,
           h_2011dh, h_2013df, h_2016gkg,
           h_2022crv, h_2025ulz]

labels  = ['1993J', '2001ig', '2003bg',
           '2011dh', '2013df', '2016gkg',
           '2022crv', 'AT2025ulz']  # <- exact text you want

plt.legend(handles=handles, labels=labels,
           loc='lower left', fontsize=14)

plt.xscale('log')
plt.yscale('log')
#plt.ylim(0.01,1.0)
plt.xlim(0.1,20000)
plt.ylim(1e23,4e28)
#plt.title (r'$L_\nu$(1.4 GHz) for SNe IIb')
plt.text(0.95, 0.95, 'L Band', transform=plt.gca().transAxes,
         fontsize=20, fontweight='bold', va='top', ha='right')
#plt.text(0.6, 0.8, 'AT2025ulz', transform=plt.gca().transAxes,
#         fontsize=14, va='top', ha='right')


plt.subplot(142)
plt.plot(sdata2001ig[:,0],sdata2001ig[:,1],color='darkgoldenrod', linewidth=2, linestyle='--')
#plt.plot(ul2001ig[:,0],ul2001ig[:,1],marker='v',markersize=14,linestyle='',markerfacecolor='goldenrod',markeredgecolor='darkgoldenrod')
plt.errorbar(sdata2001ig[:,0],sdata2001ig[:,1],yerr=sdata2001ig[:,2],marker='o',markersize=14,linestyle='',markerfacecolor='goldenrod',markeredgecolor='darkgoldenrod',ecolor='darkgoldenrod',label='2001ig')
plt.plot(sdata2011dh[:,0],sdata2011dh[:,1], color='rebeccapurple', linestyle='--', linewidth=2)
#plt.plot(ul2011dh[:,0],ul2011dh[:,1],marker='v',markersize=11,linestyle='',markerfacecolor='mediumpurple',markeredgecolor='rebeccapurple')
plt.errorbar(sdata2011dh[:,0],sdata2011dh[:,1],yerr=sdata2011dh[:,2],marker='s',markersize=12,linestyle='',markerfacecolor='mediumpurple',markeredgecolor='rebeccapurple',ecolor='rebeccapurple',label='2011dh')
plt.plot(sdata2016gkg[:,0],sdata2016gkg[:,1], color='teal', linestyle='--', linewidth=2)
#plt.plot(ul2016gkg[:,0],ul2016gkg[:,1],marker='v',markersize=11,linestyle='',markerfacecolor='cyan',markeredgecolor='teal')
plt.errorbar(sdata2016gkg[:,0],sdata2016gkg[:,1],yerr=sdata2016gkg[:,2],marker='s',markersize=12,linestyle='',markerfacecolor='cyan',markeredgecolor='teal',ecolor='teal',label='2016gkg')
#plt.plot(42,2.71e27,marker='o',markersize=20,linestyle='',mew=3,zorder=29,markerfacecolor='grey',markeredgecolor='black',label='')

plt.plot(sdata2025ulz[:,0],sdata2025ulz[:,1], color='black', linestyle='--', linewidth=3,zorder=20)
#plt.plot(xul2025ulz[:,0],xul2025ulz[:,1],marker='v',markersize=20,linestyle='',mew=3,markerfacecolor='grey',markeredgecolor='black',zorder=21)
plt.errorbar(sdet2025ulz[:,0],sdet2025ulz[:,1],yerr=sdet2025ulz[:,2],marker='o',markersize=20,mew=3,linestyle='',markerfacecolor='grey',markeredgecolor='black',ecolor='black',label='AT2025ulz',zorder=22)
#

#plt.ylabel(r'$ L_\nu$ (erg s$^{-1}$ Hz$^{-1}$))', fontsize=20)
plt.xlabel('Time (days)',fontsize=20)
plt.tick_params(which='both',direction='in',labelsize=16,length=6, width=2,labelleft=False,labelright=False,labelbottom=True,top=True,right=True)
#plt.tick_params(which='both',direction='in',labelsize=14,length=6, width=2,labelbottom=False,labelleft=False,labelright='false',top='true',right='true')
plt.legend(loc='lower left', fontsize=14)
plt.xscale('log')
plt.yscale('log')
#plt.ylim(0.01,1.0)
plt.xlim(0.1,20000)
plt.ylim(1e23,4e28)
#plt.title (r'$L_\nu$(1.4 GHz) for SNe IIb')
plt.text(0.95, 0.95, 'S Band', transform=plt.gca().transAxes,
         fontsize=20, fontweight='bold', va='top', ha='right')
#plt.text(0.43, 0.79, 'AT2025ulz', transform=plt.gca().transAxes,
#         fontsize=14, va='top', ha='right')


plt.subplot(143)
#plt.plot(time,y[0],'r-')

plt.plot(cdata1993j[:,0],cdata1993j[:,1], color='blue', linestyle='--', linewidth=2)
plt.plot(cul1993j[:,0],cul1993j[:,1],marker='v',markersize=14,linestyle='',markerfacecolor='skyblue',markeredgecolor='blue')
plt.errorbar(cdata1993j[:,0],cdata1993j[:,1],yerr=cdata1993j[:,2],marker='s',markersize=12,linestyle='',markerfacecolor='skyblue',markeredgecolor='blue',ecolor='blue',label='1993J')

plt.plot(cdata2001ig[:,0],cdata2001ig[:,1], color='darkgoldenrod', linestyle='--', linewidth=2)
#plt.plot(ul2001ig[:,0],ul2001ig[:,1],marker='v',markersize=11,linestyle='',markerfacecolor='goldenrod',markeredgecolor='darkgoldenrod')
plt.errorbar(cdata2001ig[:,0],cdata2001ig[:,1],yerr=cdata2001ig[:,2],marker='o',markersize=14,linestyle='',markerfacecolor='goldenrod',markeredgecolor='darkgoldenrod',ecolor='darkgoldenrod',label='2001ig')

plt.plot(cdata2003bg[:,0],cdata2003bg[:,1], color='peru', linestyle='--', linewidth=2)
plt.errorbar(cdata2003bg[:,0],cdata2003bg[:,1],yerr=cdata2003bg[:,2],marker='o',markersize=14,linestyle='',markerfacecolor='lightsalmon',markeredgecolor='peru',ecolor='peru',label='2003bg')

plt.plot(cdata2008ax[:,0],cdata2008ax[:,1], color='olive', linestyle='--', linewidth=2)
plt.errorbar(cdata2008ax[:,0],cdata2008ax[:,1],yerr=cdata2008ax[:,2],marker='o',markersize=14,linestyle='',markerfacecolor='yellow',markeredgecolor='olive',ecolor='olive',label='2008ax')

plt.plot(cdata2011dh[:,0],cdata2011dh[:,1], color='rebeccapurple', linestyle='--', linewidth=2)
#plt.plot(ul2011dh[:,0],ul2011dh[:,1],marker='v',markersize=11,linestyle='',markerfacecolor='mediumpurple',markeredgecolor='rebeccapurple')
plt.errorbar(cdata2011dh[:,0],cdata2011dh[:,1],yerr=cdata2011dh[:,2],marker='s',markersize=12,linestyle='',markerfacecolor='mediumpurple',markeredgecolor='rebeccapurple',ecolor='rebeccapurple',label='2011dh')

#plt.plot(xdata2011et[:,0],xdata2011et[:,1], color='magenta', linestyle='--', linewidth=2)
#plt.errorbar(xdata2011et[:,0],xdata2011et[:,1],yerr=xdata2011et[:,2],marker='o',markersize=11,linestyle='',markerfacecolor='lightpink',markeredgecolor='magenta',ecolor='magenta',label='2011et')

plt.plot(cdata2013df[:,0],cdata2013df[:,1], color='red', linestyle='--', linewidth=2)
plt.plot(cul2013df[:,0],cul2013df[:,1],marker='v',markersize=14,linestyle='',markerfacecolor='salmon',markeredgecolor='r')
plt.errorbar(cdata2013df[:,0],cdata2013df[:,1],yerr=cdata2013df[:,2],marker='s',markersize=12,linestyle='',markerfacecolor='salmon',markeredgecolor='r',ecolor='r',label='2013df')

plt.plot(cdata2016gkg[:,0],cdata2016gkg[:,1], color='teal', linestyle='--', linewidth=2)
#plt.plot(ul2016gkg[:,0],ul2016gkg[:,1],marker='v',markersize=11,linestyle='',markerfacecolor='cyan',markeredgecolor='teal')
plt.errorbar(cdata2016gkg[:,0],cdata2016gkg[:,1],yerr=cdata2016gkg[:,2],marker='s',markersize=12,linestyle='',markerfacecolor='cyan',markeredgecolor='teal',ecolor='teal',label='2016gkg')

plt.plot(cdata2022crv[:,0],cdata2022crv[:,1], color='darkseagreen', linestyle='--', linewidth=2)
#plt.plot(ul2022crv[:,0],ul2022crv[:,1],marker='v',markersize=11,linestyle='',markerfacecolor='palegreen',markeredgecolor='darkseagreen')
#plt.errorbar(xdata2022crv[:,0],xdata2022crv[:,1],yerr=xdata2022crv[:,2],marker='o',markersize=14,linestyle='',markerfacecolor='palegreen',markeredgecolor='darkseagreen',ecolor='darkseagreen',label='2022crv')

#

#plt.plot(cdata2025ulz[:,0],cdata2025ulz[:,1], color='black', linestyle='--', linewidth=3,zorder=20)
plt.plot(cul2025ulz[:,0],cul2025ulz[:,1],marker='v',markersize=20,linestyle='',mew=3,markerfacecolor='grey',markeredgecolor='black',zorder=21,label='AT2025ulz')
#plt.errorbar(cdata2025ulz[:,0],cdata2025ulz[:,1],yerr=cdata2025ulz[:,2],marker='o',markersize=20,mew=3,linestyle='',markerfacecolor='grey',markeredgecolor='black',ecolor='black',label='AT2025ulz',zorder=22)
#plt.plot(10,1.53e27,marker='o',markersize=20,linestyle='',markerfacecolor='grey',markeredgecolor='black',zorder=1_000_000)

#plt.ylabel(r'$\nu L_\nu$ (erg s$^{-1}$))', fontsize=16)
plt.xlabel('Time (days)',fontsize=20)
#plt.ylabel(r'$ L_\nu$ (erg s$^{-1}$ Hz$^{-1}$)', fontsize=20,  labelpad=20, loc='center')
plt.gca().yaxis.set_label_position("right")
plt.tick_params(which='both',direction='in',labelsize=16,length=6, width=2,labelleft=False,labelright=False,labelbottom=True,top=True,right=True)
#plt.tick_params(which='both',direction='in',labelsize=14,length=6, width=2,labelbottom=False,labelleft=False,labelright='false',top='true',right='true')
plt.legend(loc='lower left', fontsize=12.9)
plt.xscale('log')
plt.yscale('log')
plt.ylim(1e23,4e28)
plt.xlim(0.1,20000)
plt.text(0.7, 0.95, 'C Band', transform=plt.gca().transAxes,
         fontsize=20, fontweight='bold', va='top', ha='left')


plt.subplot(144)
#plt.plot(time,y[0],'r-')

plt.plot(xdata1993j[:,0],xdata1993j[:,1], color='blue', linestyle='--', linewidth=2)
plt.plot(xul1993j[:,0],xul1993j[:,1],marker='v',markersize=14,linestyle='',markerfacecolor='skyblue',markeredgecolor='blue')
plt.errorbar(xdata1993j[:,0],xdata1993j[:,1],yerr=xdata1993j[:,2],marker='s',markersize=12,linestyle='',markerfacecolor='skyblue',markeredgecolor='blue',ecolor='blue',label='1993J')

plt.plot(xdata2001ig[:,0],xdata2001ig[:,1], color='darkgoldenrod', linestyle='--', linewidth=2)
#plt.plot(ul2001ig[:,0],ul2001ig[:,1],marker='v',markersize=11,linestyle='',markerfacecolor='goldenrod',markeredgecolor='darkgoldenrod')
plt.errorbar(xdata2001ig[:,0],xdata2001ig[:,1],yerr=xdata2001ig[:,2],marker='o',markersize=14,linestyle='',markerfacecolor='goldenrod',markeredgecolor='darkgoldenrod',ecolor='darkgoldenrod',label='2001ig')

plt.plot(xdata2003bg[:,0],xdata2003bg[:,1], color='peru', linestyle='--', linewidth=2)
plt.errorbar(xdata2003bg[:,0],xdata2003bg[:,1],yerr=xdata2003bg[:,2],marker='o',markersize=14,linestyle='',markerfacecolor='lightsalmon',markeredgecolor='peru',ecolor='peru',label='2003bg')

plt.plot(xdata2008ax[:,0],xdata2008ax[:,1], color='olive', linestyle='--', linewidth=2)
plt.errorbar(xdata2008ax[:,0],xdata2008ax[:,1],yerr=xdata2008ax[:,2],marker='o',markersize=14,linestyle='',markerfacecolor='yellow',markeredgecolor='olive',ecolor='olive',label='2008ax')

plt.plot(xdata2011dh[:,0],xdata2011dh[:,1], color='rebeccapurple', linestyle='--', linewidth=2)
#plt.plot(ul2011dh[:,0],ul2011dh[:,1],marker='v',markersize=11,linestyle='',markerfacecolor='mediumpurple',markeredgecolor='rebeccapurple')
plt.errorbar(xdata2011dh[:,0],xdata2011dh[:,1],yerr=xdata2011dh[:,2],marker='s',markersize=12,linestyle='',markerfacecolor='mediumpurple',markeredgecolor='rebeccapurple',ecolor='rebeccapurple',label='2011dh')

#plt.plot(xdata2011et[:,0],xdata2011et[:,1], color='magenta', linestyle='--', linewidth=2)
#plt.errorbar(xdata2011et[:,0],xdata2011et[:,1],yerr=xdata2011et[:,2],marker='o',markersize=11,linestyle='',markerfacecolor='lightpink',markeredgecolor='magenta',ecolor='magenta',label='2011et')

plt.plot(xdata2013df[:,0],xdata2013df[:,1], color='red', linestyle='--', linewidth=2)
plt.plot(xul2013df[:,0],xul2013df[:,1],marker='v',markersize=14,linestyle='',markerfacecolor='salmon',markeredgecolor='r')
plt.errorbar(xdata2013df[:,0],xdata2013df[:,1],yerr=xdata2013df[:,2],marker='s',markersize=12,linestyle='',markerfacecolor='salmon',markeredgecolor='r',ecolor='r',label='2013df')

plt.plot(xdata2016gkg[:,0],xdata2016gkg[:,1], color='teal', linestyle='--', linewidth=2)
#plt.plot(ul2016gkg[:,0],ul2016gkg[:,1],marker='v',markersize=11,linestyle='',markerfacecolor='cyan',markeredgecolor='teal')
plt.errorbar(xdata2016gkg[:,0],xdata2016gkg[:,1],yerr=xdata2016gkg[:,2],marker='s',markersize=12,linestyle='',markerfacecolor='cyan',markeredgecolor='teal',ecolor='teal',label='2016gkg')

plt.plot(xdata2022crv[:,0],xdata2022crv[:,1], color='darkseagreen', linestyle='--', linewidth=2)
#plt.plot(ul2022crv[:,0],ul2022crv[:,1],marker='v',markersize=11,linestyle='',markerfacecolor='palegreen',markeredgecolor='darkseagreen')
plt.errorbar(xdata2022crv[:,0],xdata2022crv[:,1],yerr=xdata2022crv[:,2],marker='o',markersize=14,linestyle='',markerfacecolor='palegreen',markeredgecolor='darkseagreen',ecolor='darkseagreen',label='2022crv')



#plt.ylabel(r'$\nu L_\nu$ (erg s$^{-1}$))', fontsize=16)
plt.xlabel('Time (days)',fontsize=20)
#plt.ylabel(r'$ L_\nu$ (erg s$^{-1}$ Hz$^{-1}$)', fontsize=20,  labelpad=20, loc='center')
plt.gca().yaxis.set_label_position("right")
plt.tick_params(which='both',direction='in',labelsize=16,length=6, width=2,labelleft=False,labelright=False,labelbottom=True,top=True,right=True)
#plt.tick_params(which='both',direction='in',labelsize=14,length=6, width=2,labelbottom=False,labelleft=False,labelright='false',top='true',right='true')
plt.legend(loc='lower left', fontsize=12.9)
plt.xscale('log')
plt.yscale('log')
plt.ylim(1e23,4e28)
plt.xlim(0.1,20000)
plt.text(0.7, 0.95, 'X Band', transform=plt.gca().transAxes,
         fontsize=20, fontweight='bold', va='top', ha='left')
#plt.text(0.37, 0.77, 'AT2025ulz', transform=plt.gca().transAxes,
#         fontsize=20, va='top', ha='right')



#plt.show()
plt.savefig('New-NuLNu-IIb-LSCX.pdf')
